# %%
import pandas as pd 

wine = pd.read_csv('drive/MyDrive/winequality-red.csv')

wine.head(1000)
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0              7.4              0.70         0.00            1.90      0.076
# 1              7.8              0.88         0.00            2.60      0.098
# 2              7.8              0.76         0.04            2.30      0.092
# 3             11.2              0.28         0.56            1.90      0.075
# 4              7.4              0.70         0.00            1.90      0.076
# ..             ...               ...          ...             ...        ...
# 995            7.7              0.60         0.06            2.00      0.079
# 996            5.6              0.66         0.00            2.20      0.087
# 997            5.6              0.66         0.00            2.20      0.087
# 998            8.9              0.84         0.34            1.40      0.050
# 999            6.4              0.69         0.00            1.65      0.055
#
# ...

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
wine.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
wine.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns 

wine.hist(bins=25, figsize=(10,10))
plt.show()

# %%
plt.figure()
plt.bar(wine['quality'], wine['alcohol'], color='blue')
plt.xlabel('quality')
plt.ylabel('alcohol')
# Out:
# Text(0, 0.5, 'alcohol')

# %%
plt.figure(figsize=[19,10])
sns.heatmap(wine.corr(), annot=True)

# %%
X = wine.drop(['quality'], axis =1)
y = wine['quality']

print('Shape of X', X.shape)
print('Shape of y', y.shape)
# Out:
# Shape of X (1599, 11)
# Shape of y (1599,)

# %%
# scalling? menyeleksi feature yg bertipe numerik, tapi ini numerik semua. jd perlu g? g

from sklearn.preprocessing import StandardScaler
standard_scaler = StandardScaler()
standard_scaler.fit_transform(wine)
# Out:
# array([[-0.52835961,  0.96187667, -1.39147228, ..., -0.57920652,
#         -0.96024611, -0.78782264],
#        [-0.29854743,  1.96744245, -1.39147228, ...,  0.1289504 ,
#         -0.58477711, -0.78782264],
#        [-0.29854743,  1.29706527, -1.18607043, ..., -0.04808883,
#         -0.58477711, -0.78782264],
#        ...,
#        [-1.1603431 , -0.09955388, -0.72391627, ...,  0.54204194,
#          0.54162988,  0.45084835],
#        [-1.39015528,  0.65462046, -0.77526673, ...,  0.30598963,
#         -0.20930812, -0.78782264],
#        [-1.33270223, -1.21684919,  1.02199944, ...,  0.01092425,
#          0.54162988,  0.45084835]])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
def models(X_train, y_train):

  #Decision Tree
  from sklearn.tree import DecisionTreeClassifier
  tree = DecisionTreeClassifier()
  tree.fit(X_train, y_train)
  y_pred = tree.predict(X_test)

  print('f1', classification_report(y_test, y_pred))
  print('matrix',confusion_matrix(y_test, y_pred))
  print('acc',accuracy_score(y_test, y_pred))


  #Naive Bayes 

  from sklearn.naive_bayes import GaussianNB
  nb = GaussianNB()
  nb.fit(X_train, y_train)
  y_pred = nb.predict(X_test)

  print('f1', classification_report(y_test, y_pred))
  print('matrix',confusion_matrix(y_test, y_pred))
  print('acc',accuracy_score(y_test, y_pred))

  #KNeighbors 

  from sklearn.neighbors import KNeighborsClassifier
  neighbors = KNeighborsClassifier()
  neighbors.fit(X_train, y_train)
  y_pred = neighbors.predict(X_test)

  print('f1', classification_report(y_test, y_pred))
  print('matrix', confusion_matrix(y_test, y_pred))
  print('acc', accuracy_score(y_test, y_pred))

  print('Decision Tree acc: ', tree.score(X_train, y_train))
  print('Naive Bayes acc: ', nb.score(X_train, y_train))
  print('KNeighbors acc: ', neighbors.score(X_train, y_train))

  return tree, nb, neighbors

# %%
model =  models(X_train, y_train)
# Out:
# f1               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         2
#            4       0.33      0.18      0.24        11
#            5       0.78      0.73      0.76       135
#            6       0.72      0.69      0.71       142
#            7       0.42      0.67      0.51        27
#            8       0.00      0.00      0.00         3
#
#     accuracy                           0.68       320
#    macro avg       0.38      0.38      0.37       320
# weighted avg       0.70      0.68      0.68       320
#
# matrix [[ 0  0  0  2  0  0]
#  [ 1  2  4  3  1  0]
#  [ 2  2 99 27  5  0]
#  [ 1  2 23 98 18  0]
#  [ 0  0  1  4 18  4]
#  [ 0  0  0  2  1  0]]
# acc 0.678125
# f1               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         2
#            4       0.00      0.00      0.00        11
#            5       0.68      0.64      0.66       135
# ...

# %%
# save to joblib
